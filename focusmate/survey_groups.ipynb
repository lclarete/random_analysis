# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from data_pipeline.get_data.apis.google_spreadsheet.GoogleSheet_read_returns_df import gsheet_returns_df

# %%
df = gsheet_returns_df('Private Group Waitlist_cp1', 'Join the Private Focusmate Group Waitlist')

# %%
print(df.shape)
# Out:
#      First name   Last name               Email address  \
# 0          uday     kolluri             uday@kolluri.in
# 1        Karen          Lin     Karenlin@thelinlife.com
# 2       Russell       Adams      russell.adams@moen.com
# 3        Ronnie      Garrod      ronniegarrod@gmail.com
# 4         Wyatt    Stephens    w.stephens@bitesquad.com
# ...         ...         ...                         ...
# 1131     Volkan  Tatlikazan  volkantatlikazan@gmail.com
# 1132   Darshana    Hippargi  darshanahippargi@gmail.com
# 1133       Lige        Rose     Lige@LRHypnotherapy.com
# 1134       Eric      Kubitz             eric@kubitz.net
# 1135      Tyler      Becker         tyler@betaworks.com
#
#      Phone number (US only) Your role/title Name of your organization/group  \
# 0                6316719783           Owner            technically easy llc
# 1                6263189206             CEO               The Lin Life, LLC
# ...
