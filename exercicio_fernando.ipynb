# %%
import pandas as pd

# %%
path ='./data/suicide-death-rates.csv'

# %%
df = pd.read_csv(path)

# %%
df.rename(mapper=lambda x:x.upper(), axis=1, inplace=True)
df.head()
# Out:
#         ENTITY CODE  YEAR  \
# 0  Afghanistan  AFG  1990
# 1  Afghanistan  AFG  1991
# 2  Afghanistan  AFG  1992
# 3  Afghanistan  AFG  1993
# 4  Afghanistan  AFG  1994
#
#    DEATHS - SELF-HARM - SEX: BOTH - AGE: AGE-STANDARDIZED (RATE)
# 0                                          10.318504
# 1                                          10.327010
# 2                                          10.271411
# 3                                          10.376123
# 4                                          10.575915

# %%
df = df.rename(mapper=lambda x:x.upper(), axis='columns')
df.head()
# Out:
#         ENTITY CODE  YEAR  \
# 0  Afghanistan  AFG  1990
# 1  Afghanistan  AFG  1991
# 2  Afghanistan  AFG  1992
# 3  Afghanistan  AFG  1993
# 4  Afghanistan  AFG  1994
#
#    DEATHS - SELF-HARM - SEX: BOTH - AGE: AGE-STANDARDIZED (RATE)
# 0                                          10.318504
# 1                                          10.327010
# 2                                          10.271411
# 3                                          10.376123
# 4                                          10.575915

# %%
df.rename(mapper=lambda x:x.upper(), axis=1)
df.head()
# Out:
#         Entity Code  Year  \
# 0  Afghanistan  AFG  1990
# 1  Afghanistan  AFG  1991
# 2  Afghanistan  AFG  1992
# 3  Afghanistan  AFG  1993
# 4  Afghanistan  AFG  1994
#
#    Deaths - Self-harm - Sex: Both - Age: Age-standardized (Rate)
# 0                                          10.318504
# 1                                          10.327010
# 2                                          10.271411
# 3                                          10.376123
# 4                                          10.575915

# %%
df = df.rename(mapper = lambda x:x.upper(), axis=1)
df.head()
# Out:
#         ENTITY CODE  YEAR  \
# 0  Afghanistan  AFG  1990
# 1  Afghanistan  AFG  1991
# 2  Afghanistan  AFG  1992
# 3  Afghanistan  AFG  1993
# 4  Afghanistan  AFG  1994
#
#    DEATHS - SELF-HARM - SEX: BOTH - AGE: AGE-STANDARDIZED (RATE)
# 0                                          10.318504
# 1                                          10.327010
# 2                                          10.271411
# 3                                          10.376123
# 4                                          10.575915

# %%
serial = [i for i in range(1, len(gre_score) +1)]
serial
# Out:
# [1, 2, 3, 4, 5]

# %%
toefl_score = [337, 324, 316, 322, 314]
gre_score = [118, 107, 104, 110, 103]
serial = [i for i in range(1, len(gre_score) +1)]

data = pd.DataFrame(gre_score, toefl_score)
data.reset_index(inplace=True)
data.columns = ['gre', 'toefl']
data.index = serial
data.head()
# Out:
#    gre  toefl
# 1  337    118
# 2  324    107
# 3  316    104
# 4  322    110
# 5  314    103

# %%
data[data['toefl'] > 105]
# Out:
#    gre  toefl
# 1  337    118
# 2  324    107
# 4  322    110

# %%
data.where(data['toefl'] > 105).dropna()
# Out:
#      gre  toefl
# 1  337.0  118.0
# 2  324.0  107.0
# 4  322.0  110.0

# %%
data.where(data['toefl'] > 105)
# Out:
#      gre  toefl
# 1  337.0  118.0
# 2  324.0  107.0
# 3    NaN    NaN
# 4  322.0  110.0
# 5    NaN    NaN
